# %%
# %load_ext autoreload
# %autoreload 2

# %%
conda install -c conda-forge earthaccess
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# # All requested packages already installed.
#
#
# Note: you may need to restart the kernel to use updated packages.

# %%
import earthaccess
import pprint

# %%
auth = earthaccess.login()
# Out:
# EARTHDATA_USERNAME and EARTHDATA_PASSWORD are not set in the current environment, try setting them or use a different strategy (netrc, interactive)
# No .netrc found in /home/jovyan
# You're now authenticated with NASA Earthdata Login
# Using token with expiration date: 10/07/2023
# Using user provided credentials for EDL

# %%
query2 = earthaccess.search_datasets(
            keyword="ASTER",
)
# Out:
# Datasets found: 172

# %%
query2
# Out:
# [{
#    "meta": {
#      "revision-id": 20,
#      "deleted": false,
#      "format": "application/vnd.nasa.cmr.umm+json",
#      "provider-id": "LPCLOUD",
#      "user-id": "thouska",
#      "has-formats": false,
#      "s3-links": [
#        "s3://lp-prod-protected/ASTGTM.003, s3://lp-prod-public/ASTGTM.003"
#      ],
#      "has-spatial-subsetting": false,
#      "native-id": "ASTGTMV003",
#      "has-transforms": false,
#      "has-variables": false,
#      "concept-id": "C1711961296-LPCLOUD",
#      "revision-date": "2023-06-02T15:06:04.240Z",
#      "granule-count": 22912,
#      "has-temporal-subsetting": false,
#      "concept-type": "collection"
#    },
#    "umm": {
#      "CollectionCitations": [
#        {
#          "Title": "ASTER Global Digital Elevation Model V003",
#          "Creator": "NASA/METI/AIST/Japan Spacesystems and U.S./Japan ASTER Science Team",
#          "SeriesName": "ASTGTM.003",
#          "ReleaseDate": "2019-08-05T00:00:00.000Z",
# ...

# %%
Query = earthaccess.search_datasets(
    keyword = 'ASTER',
    cloud_hosted = True,
)
# Out:
# Datasets found: 110

# %%
results = earthaccess.search_data(
    short_name = 'AST_L1A',
    version = '003',
    cloud_hosted = True,
    bounding_box = (-134.7,58.9,-133.9,59.2),
    temporal = ('2020-03-01','2020-04-30'),
    count = 100
)
# Out:
# Granules found: 2

# %%
results
# Out:
# [Collection: {'EntryTitle': 'ASTER L1A Reconstructed Unprocessed Instrument Data V003'}
#  Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -135.122592, 'Latitude': 59.129365}, {'Longitude': -134.079012, 'Latitude': 58.974699}, {'Longitude': -133.727638, 'Latitude': 59.510847}, {'Longitude': -134.786579, 'Latitude': 59.667986}, {'Longitude': -135.122592, 'Latitude': 59.129365}]}}]}}}
#  Temporal coverage: {'SingleDateTime': '2020-04-29T20:23:55.473Z'}
#  Size(MB): 111.106
#  Data: [],
#  Collection: {'EntryTitle': 'ASTER L1A Reconstructed Unprocessed Instrument Data V003'}
# ...

# %%
[display(r) for r in results]
# Out:
# Collection: {'EntryTitle': 'ASTER L1A Reconstructed Unprocessed Instrument Data V003'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -135.122592, 'Latitude': 59.129365}, {'Longitude': -134.079012, 'Latitude': 58.974699}, {'Longitude': -133.727638, 'Latitude': 59.510847}, {'Longitude': -134.786579, 'Latitude': 59.667986}, {'Longitude': -135.122592, 'Latitude': 59.129365}]}}]}}}
# Temporal coverage: {'SingleDateTime': '2020-04-29T20:23:55.473Z'}
# Size(MB): 111.106
# Data: []
# Collection: {'EntryTitle': 'ASTER L1A Reconstructed Unprocessed Instrument Data V003'}
# Spatial coverage: {'HorizontalSpatialDomain': {'Geometry': {'GPolygons': [{'Boundary': {'Points': [{'Longitude': -135.435613, 'Latitude': 58.613207}, {'Longitude': -134.406297, 'Latitude': 58.460822}, {'Longitude': -134.06415, 'Latitude': 58.997699}, {'Longitude': -135.108379, 'Latitude': 59.152468}, {'Longitude': -135.435613, 'Latitude': 58.613207}]}}]}}}
# ...

# %%
! mkdir test_sample_data

# %%
conda install -c conda-forge ipywidgets
# Out:
# ...
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.10.3
#   latest version: 23.9.0
#
# Please update conda by running
#
#     $ conda update -n base conda
#
#
#
# ## Package Plan ##
#
#   environment location: /srv/conda
#
#   added / updated specs:
#     - ipywidgets
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     comm-0.1.4                 |     pyhd8ed1ab_0          11 KB  conda-forge
#     ipywidgets-8.1.1           |     pyhd8ed1ab_0         111 KB  conda-forge
#     jupyterlab_widgets-3.0.9   |     pyhd8ed1ab_0         182 KB  conda-forge
#     widgetsnbextension-4.0.9   |     pyhd8ed1ab_0         865 KB  conda-forge
#     ------------------------------------------------------------
#                                            Total:         1.1 MB
#
# The following NEW packages will be INSTALLED:
#
# ...

# %%
files = earthaccess.download(results, "./test_sample_data")
# Out:
#  Getting 2 granules, approx download size: 0.22 GB
# QUEUEING TASKS | : 0it [00:00, ?it/s]
# PROCESSING TASKS | : 0it [00:00, ?it/s]
# COLLECTING RESULTS | : 0it [00:00, ?it/s]
